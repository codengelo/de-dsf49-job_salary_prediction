# %% [markdown]
# # 📊 Job Salary Analysis & Visualization
#
# Analisis data untuk memahami faktor yang mempengaruhi salary.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("cleaned_job_salary.xlsx")
df.head()
# Out:
#             job_title  experience_years education_level       industry  \
# 0         AI Engineer                10        Bachelor     Healthcare
# 1        Data Analyst                 5        Bachelor        Telecom
# 2  Frontend Developer                18             PhD          Media
# 3    Business Analyst                19             PhD         Retail
# 4     Product Manager                15        Bachelor  Manufacturing
#
#   company_size   location  salary salary_category
# 0       Medium      India  109413            High
# 1        Small  Australia   93764          Medium
# 2       Medium  Singapore  148123            High
# 3       Medium     Canada  189123            High
# 4        Large     Sweden  165069            High

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   job_title         250000 non-null  str
#  1   experience_years  250000 non-null  int64
#  2   education_level   250000 non-null  str
#  3   industry          250000 non-null  str
#  4   company_size      250000 non-null  str
#  5   location          250000 non-null  str
#  6   salary            250000 non-null  int64
#  7   salary_category   250000 non-null  str
# dtypes: int64(2), str(6)
# memory usage: 15.3 MB

# %%
exp_salary = df.groupby('experience_years')['salary'].mean().sort_index()

plt.figure()
exp_salary.plot(kind='line')
plt.title('Average Salary by Experience Years')
plt.xlabel('Experience Years')
plt.ylabel('Average Salary')
plt.show()

# %%
top_jobs = df.groupby('job_title')['salary'].mean().sort_values(ascending=False).head(10)

plt.figure()
top_jobs.plot(kind='bar')
plt.title('Top 10 Highest Paying Jobs')
plt.xlabel('Job Title')
plt.ylabel('Average Salary')
plt.xticks(rotation=45)
plt.show()

# %%
industry_salary = df.groupby('industry')['salary'].mean().sort_values(ascending=False).head(10)

plt.figure()
industry_salary.plot(kind='bar')
plt.title('Average Salary by Industry')
plt.xlabel('Industry')
plt.ylabel('Average Salary')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
df['salary'].plot(kind='hist', bins=30)
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 📌 Interpretasi
#
# Visualisasi menunjukkan bahwa pengalaman kerja memiliki korelasi positif terhadap peningkatan salary. Semakin tinggi experience, rata-rata gaji juga meningkat.
#
# Selain itu, terdapat variasi signifikan antar industri dan job title, di mana beberapa posisi dan industri menawarkan rata-rata gaji yang lebih tinggi dibandingkan yang lain.
